# %% [markdown]
# # Apendizado de máquina supervisionado para classificação
#
# > O machine learning (ML) é a tarefa de receber uma entrada $\mathbf{X}$ e a saída correta $\mathbf{y}$ (supervisão) e tem que construir uma função $f$ que mapeia $\mathbf{X} \rightarrow \mathbf{y}$. No futuro podemos usar $f$ para estimar a resposta de novas entradas $\mathbf{\hat{y}}$

# %%
# !pip install --quiet pandas matplotlib seaborn scikit-learn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Blood_samples_dataset_balanced_MODIFICADO.csv")
df. sample(5)
# Out:
#       Unnamed: 0   Glucose  Cholesterol  Hemoglobin  Platelets  \
# 1089        1089  0.278161     0.471518    0.589715   0.961318
# 2111        2111  0.238341     0.624760    0.686667   1.012606
# 966          966  0.149718     0.775277    0.855435   0.362927
# 1823        1823  0.469797     0.353831    0.426228   0.118181
# 2140        2140  0.581784     0.395645    0.431056   0.120044
#
#       White Blood Cells  Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 1089           0.652815         1.258953    0.042865                 0.949393
# 2111           0.734566         0.923029    0.095872                 0.348080
# 966            0.609378         0.385761    0.489251                 0.089665
# 1823           0.105344         0.669187    0.773384                 0.578255
# 2140           0.113688         0.635670    0.602981                 0.601033
#
#       Mean Corpuscular Hemoglobin  ...     HbA1c  LDL Cholesterol  \
# 1089                     0.502800  ...  0.623395         0.538853
# 2111                     0.743164  ...  0.357828         0.485991
# 966                      0.309486  ...  0.883516         0.992824
# 1823                     1.003065  ...  0.440736         0.569982
# 2140                     1.104753  ...  0.418670         0.698885
#
#       HDL Cholesterol       ALT       AST  Heart Rate  Creatinine  Troponin  \
# 1089         1.134113  0.649887  0.551429    1.044546    0.811341  0.300025
# 2111         0.498814  0.324274  0.821907    0.935374    0.421738  0.342273
# 966          0.644145  0.646903  0.831927    0.873840    0.431420  0.422924
# 1823         0.995824  0.316513  0.368838    0.829065    0.456738  0.744146
# 2140         1.267788  0.384856  0.566526    0.904003    0.394173  0.695865
#
#       C-reactive Protein  Disease
# 1089            0.668475   Anemia
# 2111            0.422237   Anemia
# 966             0.798497   Anemia
# 1823            0.455963   Anemia
# 2140            0.343274   Anemia
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 26 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 2351 non-null   int64
#  1   Glucose                                    2351 non-null   float64
#  2   Cholesterol                                2351 non-null   float64
#  3   Hemoglobin                                 2351 non-null   float64
#  4   Platelets                                  2351 non-null   float64
#  5   White Blood Cells                          2351 non-null   float64
#  6   Red Blood Cells                            2351 non-null   float64
#  7   Hematocrit                                 2351 non-null   float64
#  8   Mean Corpuscular Volume                    2351 non-null   float64
#  9   Mean Corpuscular Hemoglobin                2351 non-null   float64
#  10  Mean Corpuscular Hemoglobin Concentration  2351 non-null   float64
#  11  Insulin                                    2351 non-null   float64
#  12  BMI                                        2351 non-null   float64
#  13  Systolic Blood Pressure                    2351 non-null   float64
#  14  Diastolic Blood Pressure                   2351 non-null   float64
#  15  Triglycerides                              2351 non-null   float64
#  16  HbA1c                                      2351 non-null   float64
#  17  LDL Cholesterol                            2351 non-null   float64
#  18  HDL Cholesterol                            2351 non-null   float64
#  19  ALT                                        2351 non-null   float64
#  20  AST                                        2351 non-null   float64
#  21  Heart Rate                                 2351 non-null   float64
#  22  Creatinine                                 2351 non-null   float64
#  23  Troponin                                   2351 non-null   float64
#  24  C-reactive Protein                         2351 non-null   float64
#  25  Disease                                    2351 non-null   object
# dtypes: float64(24), int64(1), object(1)
# memory usage: 477.7+ KB

# %%
df = df.drop("Unnamed: 0", axis=1)
df.sample(5)
# Out:
#        Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 1542  0.314627     0.493265    0.844132   0.489840           0.812387
# 2207  0.379434     0.256651    1.015384   1.100904           0.329384
# 1797  0.289163     0.685069    0.854267   0.713877           0.521145
# 1169  0.241620     0.778120    1.012885   0.847333           0.542201
# 1506  0.328146     0.298853    1.251748   0.740686           1.004156
#
#       Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 1542         1.058454    0.443275                 0.384919
# 2207         1.165824    0.049062                 0.954222
# 1797         0.807635    0.294919                 0.587978
# 1169         0.644911    0.948449                 0.610642
# 1506         0.537367    0.946913                 0.690029
#
#       Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 1542                     1.119861                                   0.699248
# 2207                     1.247162                                   1.159105
# 1797                     0.759997                                   0.427410
# 1169                     0.267929                                   1.100674
# 1506                     0.436976                                   0.709176
#
#       ...     HbA1c  LDL Cholesterol  HDL Cholesterol       ALT       AST  \
# 1542  ...  0.169214         0.475282         0.966257  0.812999  0.371861
# 2207  ...  0.830861         0.848200         0.490910  0.142019  0.601881
# 1797  ...  0.291049         0.330119         1.127962  0.328099  0.581739
# 1169  ...  0.696294         0.334322         0.436645  0.248871  0.783727
# 1506  ...  0.206834         0.443251         1.048210  0.708236  0.118356
#
#       Heart Rate  Creatinine  Troponin  C-reactive Protein   Disease
# 1542    0.894466    0.854848  0.255191            0.833156  Thalasse
# 2207    0.878633    0.352018  0.336789            0.590821    Anemia
# 1797    0.260056    0.571044  0.187099            0.265787   Healthy
# 1169    0.951812    0.262861  1.092890            0.355964  Thalasse
# 1506    0.691534    0.816281  0.430188            0.507418   Healthy
#
# [5 rows x 25 columns]

# %%
for coluna in df.columns:
    print(coluna)
    sns.catplot(data=df, x="Disease", y=coluna, kind="bar", hue="Disease") #kind pode ser boxen, box.....
    plt.show()
# Out:
# Glucose
# Cholesterol
# Hemoglobin
# Platelets
# White Blood Cells
# Red Blood Cells
# Hematocrit
# Mean Corpuscular Volume
# Mean Corpuscular Hemoglobin
# Mean Corpuscular Hemoglobin Concentration
# Insulin
# BMI
# Systolic Blood Pressure
# Diastolic Blood Pressure
# Triglycerides
# HbA1c
# LDL Cholesterol
# HDL Cholesterol
# ALT
# AST
# Heart Rate
# Creatinine
# Troponin
# C-reactive Protein
# Disease

# %%
df.columns
# Out:
# Index(['Glucose', 'Cholesterol', 'Hemoglobin', 'Platelets',
#        'White Blood Cells', 'Red Blood Cells', 'Hematocrit',
#        'Mean Corpuscular Volume', 'Mean Corpuscular Hemoglobin',
#        'Mean Corpuscular Hemoglobin Concentration', 'Insulin', 'BMI',
#        'Systolic Blood Pressure', 'Diastolic Blood Pressure', 'Triglycerides',
#        'HbA1c', 'LDL Cholesterol', 'HDL Cholesterol', 'ALT', 'AST',
#        'Heart Rate', 'Creatinine', 'Troponin', 'C-reactive Protein',
#        'Disease'],
#       dtype='object')

# %%
X = df.drop("Disease", axis = 1)
y = df["Disease"]

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
deyckson = DecisionTreeClassifier()
deyckson.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(deyckson);

# %%
from sklearn.metrics import accuracy_score

# %%
pac_aleatorio = X.sample(3, random_state=42)
pac_aleatorio
# Out:
#        Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 2236  0.166203     0.715004    0.718211   1.038445           0.791181
# 668   0.563720     0.468631    0.390634   0.580349           1.159950
# 2005  0.576591     0.864063    0.571008   1.153372           0.526875
#
#       Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 2236         0.818299    0.262325                 1.033515
# 668          0.299237    0.985401                 0.344824
# 2005         0.653220    0.942053                 1.041122
#
#       Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 2236                     0.396963                                   0.057835
# 668                      0.278967                                   0.844606
# 2005                     0.210588                                   1.227110
#
#       ...  Triglycerides     HbA1c  LDL Cholesterol  HDL Cholesterol  \
# 2236  ...       0.388513  0.747181         0.177936         1.113619
# 668   ...       1.049622  0.530250         0.863418         0.548694
# 2005  ...       0.357224  1.025883         0.334834         0.465389
#
#            ALT       AST  Heart Rate  Creatinine  Troponin  C-reactive Protein
# 2236  0.617529  0.866632    0.654956    0.366683  0.819282            0.352590
# 668   0.389320  0.300619    0.473365    0.710559  0.739672            1.029516
# 2005  0.637683  0.883233    0.322640    0.412150  1.088099            0.557686
#
# [3 rows x 24 columns]

# %%
y.iloc[2236]
# Out:
# 'Diabetes'

# %%
deyckson.predict(pac_aleatorio)
# Out:
# array(['Anemia', 'Healthy', 'Diabetes'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
y_pred = deyckson.predict(X)
accuracy_score(y, y_pred)
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
deycksonv2 = DecisionTreeClassifier()
deycksonv2.fit(X_train, y_train)
deycksonv2
# Out:
# DecisionTreeClassifier()

# %%
print(accuracy_score(y_train, deycksonv2.predict(X_train)))
print(accuracy_score(y_test, deycksonv2.predict(X_test)))
# Out:
# 1.0
# 0.904639175257732
