# %%
#!pip install matplotlib

import matplotlib.pyplot as plt # biblioteca de dataviz

# %%
plt.plot( #plot faz graficos de linha
    [2, 9, 9, 2, 2], #x
    [2, 2, 9, 9, 2] #y
)

# %%
plt.scatter( #scatter faz pontos
    [2, 9, 9, 2, 2], #x
    [2, 2, 9, 9, 2], #y
    label = "pontos do cubo",
    c="green",
    edgecolors = "pink"
)
plt.title("titulo vem aqui")
plt.xlabel("eixo x")
plt.ylabel("eixo y")
plt.legend(loc=3, bbox_to_anchor=(1, 0.5))

# %%
plt.figure()

plt.plot( #plot faz graficos de linha
    [2, 9, 9, 2, 2], #x
    [2, 2, 9, 9, 2] #y
   
)

plt.scatter( #scatter faz pontos
    [2, 9, 9, 2, 2], #x
    [2, 2, 9, 9, 2], #y
    label = "pontos do cubo",
    c="green",
    edgecolors = "pink"
)
plt.title("titulo vem aqui")
plt.xlabel("eixo x")
plt.ylabel("eixo y")
plt.legend(loc=3, bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("quadrado.pdf")
plt.show() # isso fecha a imagem para edição.. tudo tem que acontecer entre o figure e o show
# Out:
#   Cell In[24], line 6
#     c="red"
#     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2 * np.pi, 1024)
data2d = np.sin(t)[:, np.newaxis] * np.cos(t)[np.newaxis, :]

fig, ax = plt.subplots()
im = ax.imshow(data2d)
ax.set_title('Pan on the colorbar to shift the color mapping\n'
             'Zoom on the colorbar to scale the color mapping')

fig.colorbar(im, ax=ax, label='Interactive colorbar')

plt.show()

# %%
#pip install pandas
import pandas as pd
# Out:
# C:\Users\logonrmlocal\AppData\Local\Temp\ipykernel_1788\2516601420.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# o sep altera a separação de ponto e virgula para virgula. se for tabulação colocar \t
df = pd.read_csv("gaf_esp.csv", sep = ";")
#print(df)
display(df) #usa uma formatação melhor
#df
#display(df.sample(3)) #head(), tail(), sample()
# Out:
#       Espécie  Comprimento do Abdômen  Comprimento das Antenas
# 0   Gafanhoto                    0.50                      7.0
# 1   Gafanhoto                    0.50                      6.0
# 2   Gafanhoto                    0.60                      5.5
# 3   Gafanhoto                    0.65                      4.5
# 4   Gafanhoto                    0.54                      3.2
# ..        ...                     ...                      ...
# 95  Esperança                    9.75                      6.2
# 96  Esperança                    6.20                      8.1
# 97  Esperança                    9.20                      4.7
# 98  Esperança                    9.10                      6.0
# 99  Esperança                    8.29                      7.0
#
# [100 rows x 3 columns]

# %%
df["Comprimento do Abdômen"] #mostra so o comprimento do abdomen pega so a coluna do colchete
# Out:
# 0     0.50
# 1     0.50
# 2     0.60
# 3     0.65
# 4     0.54
#       ...
# 95    9.75
# 96    6.20
# 97    9.20
# 98    9.10
# 99    8.29
# Name: Comprimento do Abdômen, Length: 100, dtype: float64

# %%
df.iloc[2],#o .iloc pega a linha inteira do indice entre[]
df.iloc[2]["Comprimento do Abdômen"]#pega so a coluna daquela linha
# Out:
# 0.6

# %%
plt.plot(
    df["Comprimento das Antenas"],
    df["Comprimento do Abdômen"]
)

# %%
plt.scatter(
    df["Comprimento das Antenas"],
    df["Comprimento do Abdômen"]
)

# %%
# !pip install seaborn

import seaborn as sns

# %%
sns.scatterplot(df,
    x="Comprimento das Antenas",
    y="Comprimento do Abdômen",
    hue="Espécie"

)
# Out:
# <Axes: xlabel='Comprimento das Antenas', ylabel='Comprimento do Abdômen'>
